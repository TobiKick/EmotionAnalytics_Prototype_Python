# %%
############################# IMPORT STATEMENTS ########################################################
#Import Python modules
import numpy as np
from matplotlib import pyplot as plt
from mtcnn.mtcnn import MTCNN
from numpy import asarray
from PIL import Image
from matplotlib.patches import Rectangle

#For local CPU usage:
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

#Import Keras modules
from keras.layers import Dense, Flatten, Input, Dropout, Conv1D, Conv2D, LSTM, Concatenate, Reshape, MaxPool1D, MaxPool2D, BatchNormalization
from keras import Model
from keras.optimizers import Adam
from keras.utils import np_utils
import keras.backend as K

# %%
############################# SETUP PROJECT PARAMETERS ########################################################
LOAD_PROGRESS_FROM_MODEL = False
SAVE_PROGRESS_TO_MODEL = True

IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224

DATA_DIR = 'C:/Users/Tobias/Desktop/Master-Thesis/Data/facesdb/s005/tif/training/'
DISPLAY_IMG_NAME = 's005-04_img.tif'

# %%
if LOAD_PROGRESS_FROM_MODEL:
    vgg_model.load_weights("model_checkpoints/vgg_model.h5")
    print("Loaded model from disk")

# %% [markdown]
# # Approach:
#
# ### 1. Face detection
# using MTCNN (Simultaneous face detection, face alignment, bounding boxing and landmark detection)
#
# ### 2. Highlighting faces
# draw the bounding box in an image and plot it - to check out the result
#
# ### 3. Face extraction
# extracting the face according to the identified bounding box
#
# ### 4. Face recognition
# Using the VGGFace pretrained Resnet50 model to recognize emotions (training + prediction)

# %% [markdown]
# ## 0. Get data

# %%
def get_image_from_filename(path_to_folder, filename):
    image = cv2.cvtColor(cv2.imread(path_to_folder + filename), cv2.COLOR_BGR2RGB)
    return image

def get_images_from_folder(path_to_folder):
    images = []
    for filename in os.listdir(path_to_folder):
        img = cv2.cvtColor(cv2.imread(os.path.join(path_to_folder,filename)), cv2.COLOR_BGR2RGB)
        if img is not None:
            images.append(img)
    return images

# %% [markdown]
#
# ## 1. Face detection

# %%
import cv2
import os

detector = MTCNN()

def detect_face(path_to_folder, filename):
    image = get_image_from_filename(path_to_folder, filename)
    face = detector.detect_faces(image)
    return np.array(face)

def detect_faces(path_to_folder):
    images = get_images_from_folder(path_to_folder)
    faces = []  
    for img in images:
        face = detector.detect_faces(img)
        faces.append(face)
    return faces

# %%
detect_face(DATA_DIR, DISPLAY_IMG_NAME)
# Out:
# array([{'box': [208, 124, 215, 285], 'confidence': 0.9997768998146057, 'keypoints': {'left_eye': (268, 247), 'right_eye': (366, 244), 'nose': (320, 317), 'mouth_left': (283, 355), 'mouth_right': (360, 351)}}],
#       dtype=object)

# %%
faces = detect_faces(DATA_DIR)
print(faces[0])
# Out:
# [{'box': [208, 124, 215, 285], 'confidence': 0.9997768998146057, 'keypoints': {'left_eye': (268, 247), 'right_eye': (366, 244), 'nose': (320, 317), 'mouth_left': (283, 355), 'mouth_right': (360, 351)}}]

# %% [markdown]
# ## 2. Higlighting face

# %%
def highlight_face(path_to_folder, filename):
  # display image
    image = get_image_from_filename(path_to_folder, filename)
    plt.imshow(image)

    ax = plt.gca()
    face = detect_face(path_to_folder, filename)
    
    # for each face in the image, draw a rectangle based on coordinates
    for elem in face:
        x, y, width, height = elem['box']
        face_border = Rectangle((x, y), width, height,
                          fill=False, color='red')
        ax.add_patch(face_border)
    plt.show()

# %%
highlight_face(DATA_DIR, DISPLAY_IMG_NAME)

# %% [markdown]
# ## 3. Face extraction

# %%
def extract_face_from_image(path_to_folder, filename, required_size=(IMAGE_HEIGHT, IMAGE_WIDTH)):
    face = detect_face(path_to_folder, filename)

    # extract the bounding box from the requested face
    x1, y1, width, height = face[0]['box']
    x2, y2 = x1 + width, y1 + height
        
    # extract the face
    face_boundary = image[y1:y2, x1:x2]

    # resize pixels to the model size
    face_image = Image.fromarray(face_boundary)
    face_image = face_image.resize(required_size)
    face_array = asarray(face_image)
        
    return face_array


def extract_faces_from_images(path_to_folder, required_size=(IMAGE_HEIGHT, IMAGE_WIDTH)):
    faces = detect_faces(path_to_folder)
    face_images = []
    
    for face in faces:
        # extract the bounding box from the requested face
        x1, y1, width, height = face[0]['box']
        x2, y2 = x1 + width, y1 + height

        # extract the face
        face_boundary = image[y1:y2, x1:x2]

        # resize pixels to the model size
        face_image = Image.fromarray(face_boundary)
        face_image = face_image.resize(required_size)
        face_array = asarray(face_image)
        face_images.append(face_array)
    return face_images

# %%
# Display the first face from the extracted faces
extracted_face = extract_face_from_image(DATA_DIR, DISPLAY_IMG_NAME)
plt.imshow(extracted_face)
plt.show()
extracted_face.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# ## 4. Face recognition

# %%
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

# %%
def get_face_embedding(faces):
    samples = asarray(faces, 'float32')

    # prepare the data for the model
    samples = preprocess_input(samples, version=2)

    # create a vggface model object
    model = VGGFace(model='resnet50',
        include_top=False,
        input_shape=(224, 224, 3),
        pooling='avg')
    
    # perform prediction
    return model.predict(samples)

# %%
faces = extract_faces_from_images(DATA_DIR)
model_scores = get_face_embedding(faces)

# %%
#the model returns a vector, which represents the features of a face
print(model_scores)
# Out:
# [[ 0.0163375   0.          5.8658085  ...  3.72699     2.6045728
#    0.        ]
#  [ 0.49037382  0.         10.340538   ...  4.3940535   3.5933821
#    0.        ]]

# %%
# NOW: Create own top for this VGG model
vgg_model = VGGFace(model='resnet50', include_top=False, input_shape=(224, 224, 3), pooling='avg')
last_layer = vgg_model.get_layer('avg_pool').output
x = Flatten(name='flatten')(last_layer)
x = Dense(512, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(64, activation='relu')(x)
out = Dense(2, activation='sigmoid', name='classifier')(x)
custom_vgg_model = Model(vgg_model.input, out)

# %%
# train model
vgg_model.fit(x_train, y_train, epochs=2)

## vgg_model.fit(x_train, y_train, batch_size=64, epochs=2, validation_split=0.2)

# %%
# use model for prediction
def predict_emotions(faces):
    samples = asarray(faces, 'float32')

    # prepare the data for the model
    samples = preprocess_input(samples, version=2)
    
    # perform prediction
    return custom_vgg_model.predict(samples)

# %%
faces = extract_faces_from_images(DATA_DIR)
emotion_scores = predict_emtions(faces)

# %%
# the model returns the emtions in 2-dimensional Valance-Arousal space
print(emotion_scores)

# %%
if SAVE_PROGRESS_TO_MODEL:
    vgg_model.save_weights("model_checkpoints/vgg_model.h5")
    print("Saved model to disk")
# Out:
# Saved model to disk
